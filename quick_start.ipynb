# %%
import torch
from transformers import LlamaForCausalLM, LlamaTokenizer

model_id="./hf/7b"

tokenizer = LlamaTokenizer.from_pretrained(model_id)

model =LlamaForCausalLM.from_pretrained(model_id, load_in_8bit=True, device_map='auto', torch_dtype=torch.float16)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|██████████| 3/3 [00:25<00:00,  8.59s/it]

# %%
eval_prompt = """
Read this report and return 0 if fracture is absent, if fracture is present 1: 
Report:
"COMMINUTED, MILDLY DISPLACED AND MILDLY ANGULATED DISTAL RADIAL
FRACTURE WITH INTRA-ARTICULAR EXTENSION. ASSOCIATED SOFT TISSUE EDEMA.
MILDLY ANGULATED FRACTURE THROUGH THE DISTAL 5TH METACARPAL

Findings: 1"
"Report:  
RIGHT FOOT: NO ACUTE OSSEOUS ABNORMALITY.
 
RIGHT ANKLE:  NO ACUTE OSSEOUS ABNORMALITY.
 
RIGHT TIBIA AND FIBULA:  NO ACUTE OSSEOUS ABNORMALITY.
Finding: "
"
"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=100)[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Read this report and return 0 if fracture is absent, if fracture is present 1:
# Report:
# "COMMINUTED, MILDLY DISPLACED AND MILDLY ANGULATED DISTAL RADIAL
# FRACTURE WITH INTRA-ARTICULAR EXTENSION. ASSOCIATED SOFT TISSUE EDEMA.
# MILDLY ANGULATED FRACTURE THROUGH THE DISTAL 5TH METACARPAL
#
# Findings: 1"
# "Report:
# RIGHT FOOT: NO ACUTE OSSEOUS ABNORMALITY.
#
# RIGHT ANKLE:  NO ACUTE OSSEOUS ABNORMALITY.
#
# RIGHT TIBIA AND FIBULA:  NO ACUTE OSSEOUS ABNORMALITY.
# Finding: "
# "

# %%
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Read this report and return 0 if fracture is absent, otherswise 1: ""
# COMMINUTED, MILDLY DISPLACED AND MILDLY ANGULATED DISTAL RADIAL
# FRACTURE WITH INTRA-ARTICULAR EXTENSION. ASSOCIATED SOFT TISSUE EDEMA.
# MILDLY ANGULATED FRACTURE THROUGH THE DISTAL 5TH METACARPAL"
# "
